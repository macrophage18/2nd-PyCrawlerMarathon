# %%
import requests

r = requests.get('https://cat-fact.herokuapp.com/facts')
r.text
# Out:
# '[{"status":{"verified":true,"sentCount":1},"type":"cat","deleted":false,"_id":"58e008800aac31001185ed07","user":"58e007480aac31001185ecef","text":"Wikipedia has a recording of a cat meowing, because why not?","__v":0,"source":"user","updatedAt":"2020-08-23T20:20:01.611Z","createdAt":"2018-03-06T21:20:03.505Z","used":false},{"status":{"verified":true,"sentCount":1},"type":"cat","deleted":false,"_id":"58e008630aac31001185ed01","user":"58e007480aac31001185ecef","text":"When cats grimace, they are usually \\"taste-scenting.\\" They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.","__v":0,"source":"user","updatedAt":"2020-08-23T20:20:01.611Z","createdAt":"2018-02-07T21:20:02.903Z","used":false},{"status":{"verified":true,"sentCount":1},"type":"cat","deleted":false,"_id":"58e00a090aac31001185ed16","user":"58e007480aac31001185ecef","text":"Cats make more than 100 different sounds whereas dogs make around 10.","__v":0,"source":"user","updatedAt
# ...

# %%
import requests

r = requests.get('https://www.travel.taipei/open-api/swagger/docs/V1')
r.text
# Out:
# '{"swagger":"2.0","info":{"version":"V1","title":"旅遊資訊API","description":"本開放資料平台透過swagger套件提供。<br />\\r\\n                            如需要更詳盡的資料開放訊息，請至 <a href=\\"https://data.taipei\\" target=\\"_blank\\" title=\\"臺北市政府開放資料平台\\">臺北市政府開放資料平台</a>。","x-swagger-net-version":"8.3.21.001"},"host":"www.travel.taipei","basePath":"/open-api","schemes":["https"],"paths":{"/{lang}/Attractions/All":{"get":{"tags":["Attractions"],"summary":"景點","operationId":"Attractions_All","consumes":[],"produces":["application/json","text/json","application/xml","text/xml"],"parameters":[{"name":"lang","in":"path","description":"語系代碼\\r\\n<ul><li>zh-tw   -正體中文</li><li>zh-cn   -簡體中文</li><li>en      -英文</li><li>ja      -日文</li><li>ko      -韓文</li><li>es      -西班牙文</li><li>id      -印尼文</li><li>th      -泰文</li><li>vi      -越南文</li></ul>","required":true,"type":"string"},{"name":"categoryIds","in":"query","description":"查詢的分類編號(可輸入多個請以逗號,分隔)。例如 12,34,124","required":false,"type":"string","default":""},{"name":"nl
# ...

# %%
import requests

r = requests.get('http://odata.wra.gov.tw/v4/RealtimeWaterLevel')
r.text
# Out:
# '{"@odata.context": "http://odata.wra.gov.tw/v4/$metadata#RealtimeWaterLevel",\n"@odata.count": 0,\n"value": []}'

# %%
import json
r = requests.post('https://www.travel.taipei/open-api/swagger/docs/V1', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'swagger': '2.0',
#  'info': {'version': 'V1',
#   'title': '旅遊資訊API',
#   'description': '本開放資料平台透過swagger套件提供。<br />\r\n                            如需要更詳盡的資料開放訊息，請至 <a href="https://data.taipei" target="_blank" title="臺北市政府開放資料平台">臺北市政府開放資料平台</a>。',
#   'x-swagger-net-version': '8.3.21.001'},
#  'host': 'www.travel.taipei',
#  'basePath': '/open-api',
#  'schemes': ['https'],
#  'paths': {'/{lang}/Attractions/All': {'get': {'tags': ['Attractions'],
#     'summary': '景點',
#     'operationId': 'Attractions_All',
#     'consumes': [],
#     'produces': ['application/json',
#      'text/json',
#      'application/xml',
#      'text/xml'],
#     'parameters': [{'name': 'lang',
#       'in': 'path',
#       'description': '語系代碼\r\n<ul><li>zh-tw   -正體中文</li><li>zh-cn   -簡體中文</li><li>en      -英文</li><li>ja      -日文</li><li>ko      -韓文</li><li>es      -西班牙文</li><li>id      -印尼文</li><li>th      -泰文</li><li>vi      -越南文</li></ul>',
#       'required': True,
#       'type': 'string'},
# ...

# %%
import json

r = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(r.text)
# Out:
# [{'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '58e008800aac31001185ed07',
#   'user': '58e007480aac31001185ecef',
#   'text': 'Wikipedia has a recording of a cat meowing, because why not?',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'createdAt': '2018-03-06T21:20:03.505Z',
#   'used': False},
#  {'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '58e008630aac31001185ed01',
#   'user': '58e007480aac31001185ecef',
#   'text': 'When cats grimace, they are usually "taste-scenting." They have an extra organ that, with some breathing control, allows the cats to taste-sense the air.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'createdAt': '2018-02-07T21:20:02.903Z',
#   'used': False},
#  {'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
# ...
